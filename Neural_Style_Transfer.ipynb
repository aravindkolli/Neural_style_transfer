# %%
#with reference from deep learning with python-francois chollet

# %%
from keras.preprocessing.image import load_img, img_to_array

# This is the path to the image you want to transform.
target_image_path = 'willy_wonka_old.jpg'
# This is the path to the style image.
style_reference_image_path = 'style2.jpg'

# Dimensions of the generated picture.
width, height = load_img(target_image_path).size
img_height = 400
img_width = int(width * img_height / height)
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
print(target_image_path)
# Out:
# willy_wonka_old.jpg

# %%
import numpy as np
from keras.applications import vgg19

def preprocess_image(image_path):
    img = load_img(image_path, target_size=(img_height, img_width))
    img = img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img = vgg19.preprocess_input(img)
    return img

def deprocess_image(x):
    # Remove zero-center by mean pixel
    x[:, :, 0] += 103.939
    x[:, :, 1] += 116.779
    x[:, :, 2] += 123.68
    # 'BGR'->'RGB'
    x = x[:, :, ::-1]
    x = np.clip(x, 0, 255).astype('uint8')
    return x

# %%
from keras import backend as K

target_image = K.constant(preprocess_image(target_image_path))
style_reference_image = K.constant(preprocess_image(style_reference_image_path))

# This placeholder will contain our generated image
combination_image = K.placeholder((1, img_height, img_width, 3))

# We combine the 3 images into a single batch
input_tensor = K.concatenate([target_image,
                              style_reference_image,
                              combination_image], axis=0)

# We build the VGG19 network with our batch of 3 images as input.
# The model will be loaded with pre-trained ImageNet weights.
model = vgg19.VGG19(input_tensor=input_tensor,
                    weights='imagenet',
                    include_top=False)
print('Model loaded.')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 7s 0us/step
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# Model loaded.

# %%
print(target_image)
# Out:
# Tensor("Const:0", shape=(1, 400, 400, 3), dtype=float32)

# %%
print(style_reference_image)
# Out:
# Tensor("Const_1:0", shape=(1, 400, 400, 3), dtype=float32)

# %%
print(combination_image)
# Out:
# Tensor("Placeholder:0", shape=(1, 400, 400, 3), dtype=float32)

# %%
print(input_tensor)
# Out:
# Tensor("concat:0", shape=(3, 400, 400, 3), dtype=float32)

# %%
def content_loss(base, combination):
    return K.sum(K.square(combination - base))

# %%
def gram_matrix(x):
    features = K.batch_flatten(K.permute_dimensions(x, (2, 0, 1)))
    gram = K.dot(features, K.transpose(features))
    return gram


def style_loss(style, combination):
    S = gram_matrix(style)
    C = gram_matrix(combination)
    channels = 3
    size = img_height * img_width
    return K.sum(K.square(S - C)) / (4. * (channels ** 2) * (size ** 2))

# %%
def total_variation_loss(x):
    a = K.square(
        x[:, :img_height - 1, :img_width - 1, :] - x[:, 1:, :img_width - 1, :])
    b = K.square(
        x[:, :img_height - 1, :img_width - 1, :] - x[:, :img_height - 1, 1:, :])
    return K.sum(K.pow(a + b, 1.25))

# %%
# Dict mapping layer names to activation tensors
outputs_dict = dict([(layer.name, layer.output) for layer in model.layers])
# Name of layer used for content loss
content_layer = 'block5_conv2'
# Name of layers used for style loss
style_layers = ['block1_conv1',
                'block2_conv1',
                'block3_conv1',
                'block4_conv1',
                'block5_conv1']
# Weights in the weighted average of the loss components
total_variation_weight = 1e-4
style_weight = 1.
content_weight = 0.025

# Define the loss by adding all components to a `loss` variable
loss = K.variable(0.)
layer_features = outputs_dict[content_layer]
target_image_features = layer_features[0, :, :, :]
combination_features = layer_features[2, :, :, :]
loss += content_weight * content_loss(target_image_features,
                                      combination_features)
for layer_name in style_layers:
    layer_features = outputs_dict[layer_name]
    style_reference_features = layer_features[1, :, :, :]
    combination_features = layer_features[2, :, :, :]
    sl = style_loss(style_reference_features, combination_features)
    loss += (style_weight / len(style_layers)) * sl
loss += total_variation_weight * total_variation_loss(combination_image)
# Out:
# WARNING:tensorflow:Variable += will be deprecated. Use variable.assign_add if you want assignment to the variable value or 'x = x + y' if you want a new python Tensor object.

# %%
print(outputs_dict)
# Out:
# {'input_1': <tf.Tensor 'concat:0' shape=(3, 400, 400, 3) dtype=float32>, 'block1_conv1': <tf.Tensor 'block1_conv1/Relu:0' shape=(3, 400, 400, 64) dtype=float32>, 'block1_conv2': <tf.Tensor 'block1_conv2/Relu:0' shape=(3, 400, 400, 64) dtype=float32>, 'block1_pool': <tf.Tensor 'block1_pool/MaxPool:0' shape=(3, 200, 200, 64) dtype=float32>, 'block2_conv1': <tf.Tensor 'block2_conv1/Relu:0' shape=(3, 200, 200, 128) dtype=float32>, 'block2_conv2': <tf.Tensor 'block2_conv2/Relu:0' shape=(3, 200, 200, 128) dtype=float32>, 'block2_pool': <tf.Tensor 'block2_pool/MaxPool:0' shape=(3, 100, 100, 128) dtype=float32>, 'block3_conv1': <tf.Tensor 'block3_conv1/Relu:0' shape=(3, 100, 100, 256) dtype=float32>, 'block3_conv2': <tf.Tensor 'block3_conv2/Relu:0' shape=(3, 100, 100, 256) dtype=float32>, 'block3_conv3': <tf.Tensor 'block3_conv3/Relu:0' shape=(3, 100, 100, 256) dtype=float32>, 'block3_conv4': <tf.Tensor 'block3_conv4/Relu:0' shape=(3, 100, 100, 256) dtype=float32>, 'block3_pool': <tf.Tensor 'block3_pool/MaxPool:0' shape=(3, 50, 50, 256) dtype=float32>, 'block4_conv1': <tf.Tensor 'block4_conv1/Relu:0' shape=(3, 50, 50, 512) dtype=float32>, 'block4_conv2': <tf.Tensor 'block4_conv2/Relu:0' shape=(3, 50, 50, 512) dtype=float32>, 'block4_conv3': <tf.Tensor 'block4_conv3/Relu:0' shape=(3, 50, 50, 512) dtype=float32>, 'block4_conv4': <tf.Tensor 'block4_conv4/Relu:0' shape=(3, 50, 50, 512) dtype=float32>, 'block4_pool': <tf.Tensor 'block4_pool/MaxPool:0' shape=(3, 25, 25, 512) dtype=float32>, 'block5_conv1': <tf.Tensor 'block5_conv1/Relu:0' shape=(3, 25, 25, 512) dtype=float32>, 'block5_conv2': <tf.Tensor 'block5_conv2/Relu:0' shape=(3, 25, 25, 512) dtype=float32>, 'block5_conv3': <tf.Tensor 'block5_conv3/Relu:0' shape=(3, 25, 25, 512) dtype=float32>, 'block5_conv4': <tf.Tensor 'block5_conv4/Relu:0' shape=(3, 25, 25, 512) dtype=float32>, 'block5_pool': <tf.Tensor 'block5_pool/MaxPool:0' shape=(3, 12, 12, 512) dtype=float32>}

# %%
print(layer_features)
# Out:
# Tensor("block5_conv1/Relu:0", shape=(3, 25, 25, 512), dtype=float32)

# %%
print(target_image_features)
# Out:
# Tensor("strided_slice:0", shape=(25, 25, 512), dtype=float32)

# %%
print(combination_features)
# Out:
# Tensor("strided_slice_19:0", shape=(25, 25, 512), dtype=float32)

# %%
# Get the gradients of the generated image wrt the loss
grads = K.gradients(loss, combination_image)[0]

# Function to fetch the values of the current loss and the current gradients
fetch_loss_and_grads = K.function([combination_image], [loss, grads])


class Evaluator(object):

    def __init__(self):
        self.loss_value = None
        self.grads_values = None

    def loss(self, x):
        assert self.loss_value is None
        x = x.reshape((1, img_height, img_width, 3))
        outs = fetch_loss_and_grads([x])
        loss_value = outs[0]
        grad_values = outs[1].flatten().astype('float64')
        self.loss_value = loss_value
        self.grad_values = grad_values
        return self.loss_value

    def grads(self, x):
        assert self.loss_value is not None
        grad_values = np.copy(self.grad_values)
        self.loss_value = None
        self.grad_values = None
        return grad_values

evaluator = Evaluator()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1375: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
print(grads)
# Out:
# Tensor("gradients/AddN_16:0", shape=(1, 400, 400, 3), dtype=float32)

# %%
print(fetch_loss_and_grads)
# Out:
# <keras.backend.tensorflow_backend.Function object at 0x7f4ab90db400>

# %%
from scipy.optimize import fmin_l_bfgs_b
import time
import imageio

result_prefix = 'style_transfer_result'
iterations = 150

# Run scipy-based optimization (L-BFGS) over the pixels of the generated image
# so as to minimize the neural style loss.
# This is our initial state: the target image.
# Note that `scipy.optimize.fmin_l_bfgs_b` can only process flat vectors.
x = preprocess_image(target_image_path)
x = x.flatten()
for i in range(iterations):
    print('Start of iteration', i)
    start_time = time.time()
    x, min_val, info = fmin_l_bfgs_b(evaluator.loss, x,
                                     fprime=evaluator.grads, maxfun=20)
    print('Current loss value:', min_val)
    # Save current generated image
    img = x.copy().reshape((img_height, img_width, 3))
    img = deprocess_image(img)
    fname = result_prefix + '_at_iteration_%d.png' % i
    imageio.imwrite(fname, img)
    end_time = time.time()
    print('Image saved as', fname)
    print('Iteration %d completed in %ds' % (i, end_time - start_time))
# Out:
# Start of iteration 0
# Current loss value: 9872136000.0
# Image saved as style_transfer_result_at_iteration_0.png
# Iteration 0 completed in 20s
# Start of iteration 1
# Current loss value: 2965752800.0
# Image saved as style_transfer_result_at_iteration_1.png
# Iteration 1 completed in 11s
# Start of iteration 2
# Current loss value: 1654294800.0
# Image saved as style_transfer_result_at_iteration_2.png
# Iteration 2 completed in 11s
# Start of iteration 3
# Current loss value: 1126420900.0
# Image saved as style_transfer_result_at_iteration_3.png
# Iteration 3 completed in 12s
# Start of iteration 4
# Current loss value: 846452900.0
# Image saved as style_transfer_result_at_iteration_4.png
# Iteration 4 completed in 11s
# Start of iteration 5
# Current loss value: 683091500.0
# Image saved as style_transfer_result_at_iteration_5.png
# Iteration 5 completed in 11s
# Start of iteration 6
# Current loss value: 579250900.0
# Image saved as style_transfer_result_at_iteration_6.png
# Iteration 6 completed in 12s
# Start of iteration 7
# Current loss value: 498777440.0
# Image saved as style_transfer_result_at_iteration_7.png
# Iteration 7 completed in 12s
# Start of iteration 8
# Current loss value: 435688700.0
# Image saved as style_transfer_result_at_iteration_8.png
# Iteration 8 completed in 11s
# Start of iteration 9
# Current loss value: 392655580.0
# Image saved as style_transfer_result_at_iteration_9.png
# Iteration 9 completed in 11s
# Start of iteration 10
# Current loss value: 335918200.0
# Image saved as style_transfer_result_at_iteration_10.png
# Iteration 10 completed in 12s
# Start of iteration 11
# Current loss value: 301707600.0
# Image saved as style_transfer_result_at_iteration_11.png
# Iteration 11 completed in 11s
# Start of iteration 12
# Current loss value: 271508130.0
# Image saved as style_transfer_result_at_iteration_12.png
# Iteration 12 completed in 11s
# Start of iteration 13
# Current loss value: 251144140.0
# Image saved as style_transfer_result_at_iteration_13.png
# Iteration 13 completed in 12s
# Start of iteration 14
# Current loss value: 233386180.0
# Image saved as style_transfer_result_at_iteration_14.png
# Iteration 14 completed in 11s
# Start of iteration 15
# Current loss value: 220308260.0
# Image saved as style_transfer_result_at_iteration_15.png
# Iteration 15 completed in 11s
# Start of iteration 16
# Current loss value: 205605250.0
# Image saved as style_transfer_result_at_iteration_16.png
# Iteration 16 completed in 11s
# Start of iteration 17
# Current loss value: 191257200.0
# Image saved as style_transfer_result_at_iteration_17.png
# Iteration 17 completed in 12s
# Start of iteration 18
# Current loss value: 181903420.0
# Image saved as style_transfer_result_at_iteration_18.png
# Iteration 18 completed in 12s
# Start of iteration 19
# Current loss value: 174393580.0
# Image saved as style_transfer_result_at_iteration_19.png
# Iteration 19 completed in 11s
# Start of iteration 20
# Current loss value: 164054380.0
# Image saved as style_transfer_result_at_iteration_20.png
# Iteration 20 completed in 11s
# Start of iteration 21
# Current loss value: 154960110.0
# Image saved as style_transfer_result_at_iteration_21.png
# Iteration 21 completed in 11s
# Start of iteration 22
# Current loss value: 150411380.0
# Image saved as style_transfer_result_at_iteration_22.png
# Iteration 22 completed in 11s
# Start of iteration 23
# Current loss value: 146176560.0
# Image saved as style_transfer_result_at_iteration_23.png
# Iteration 23 completed in 11s
# Start of iteration 24
# Current loss value: 141551360.0
# Image saved as style_transfer_result_at_iteration_24.png
# Iteration 24 completed in 12s
# Start of iteration 25
# Current loss value: 137377180.0
# Image saved as style_transfer_result_at_iteration_25.png
# Iteration 25 completed in 11s
# Start of iteration 26
# Current loss value: 134520860.0
# Image saved as style_transfer_result_at_iteration_26.png
# Iteration 26 completed in 11s
# Start of iteration 27
# Current loss value: 131903640.0
# Image saved as style_transfer_result_at_iteration_27.png
# Iteration 27 completed in 11s
# Start of iteration 28
# Current loss value: 129168020.0
# Image saved as style_transfer_result_at_iteration_28.png
# Iteration 28 completed in 11s
# Start of iteration 29
# Current loss value: 126851310.0
# Image saved as style_transfer_result_at_iteration_29.png
# Iteration 29 completed in 11s
# Start of iteration 30
# Current loss value: 123256340.0
# Image saved as style_transfer_result_at_iteration_30.png
# Iteration 30 completed in 12s
# Start of iteration 31
# Current loss value: 120231580.0
# Image saved as style_transfer_result_at_iteration_31.png
# Iteration 31 completed in 11s
# Start of iteration 32
# Current loss value: 117510104.0
# Image saved as style_transfer_result_at_iteration_32.png
# Iteration 32 completed in 11s
# Start of iteration 33
# Current loss value: 115414420.0
# Image saved as style_transfer_result_at_iteration_33.png
# Iteration 33 completed in 11s
# Start of iteration 34
# Current loss value: 113207910.0
# Image saved as style_transfer_result_at_iteration_34.png
# Iteration 34 completed in 11s
# Start of iteration 35
# Current loss value: 110858970.0
# Image saved as style_transfer_result_at_iteration_35.png
# Iteration 35 completed in 12s
# Start of iteration 36
# Current loss value: 109442210.0
# Image saved as style_transfer_result_at_iteration_36.png
# Iteration 36 completed in 11s
# Start of iteration 37
# Current loss value: 107909690.0
# Image saved as style_transfer_result_at_iteration_37.png
# Iteration 37 completed in 12s
# Start of iteration 38
# Current loss value: 106389336.0
# Image saved as style_transfer_result_at_iteration_38.png
# Iteration 38 completed in 11s
# Start of iteration 39
# Current loss value: 105329120.0
# Image saved as style_transfer_result_at_iteration_39.png
# Iteration 39 completed in 12s
# Start of iteration 40
# Current loss value: 104002850.0
# Image saved as style_transfer_result_at_iteration_40.png
# Iteration 40 completed in 11s
# Start of iteration 41
# Current loss value: 102615544.0
# Image saved as style_transfer_result_at_iteration_41.png
# Iteration 41 completed in 12s
# Start of iteration 42
# Current loss value: 101522030.0
# Image saved as style_transfer_result_at_iteration_42.png
# Iteration 42 completed in 11s
# Start of iteration 43
# Current loss value: 100505064.0
# Image saved as style_transfer_result_at_iteration_43.png
# Iteration 43 completed in 11s
# Start of iteration 44
# Current loss value: 99336490.0
# Image saved as style_transfer_result_at_iteration_44.png
# Iteration 44 completed in 11s
# Start of iteration 45
# Current loss value: 98341550.0
# Image saved as style_transfer_result_at_iteration_45.png
# Iteration 45 completed in 11s
# Start of iteration 46
# Current loss value: 97333450.0
# Image saved as style_transfer_result_at_iteration_46.png
# Iteration 46 completed in 11s
# Start of iteration 47
# Current loss value: 96225620.0
# Image saved as style_transfer_result_at_iteration_47.png
# Iteration 47 completed in 11s
# Start of iteration 48
# Current loss value: 95299790.0
# Image saved as style_transfer_result_at_iteration_48.png
# Iteration 48 completed in 11s
# Start of iteration 49
# Current loss value: 94576760.0
# Image saved as style_transfer_result_at_iteration_49.png
# Iteration 49 completed in 11s
# Start of iteration 50
# Current loss value: 93372504.0
# Image saved as style_transfer_result_at_iteration_50.png
# Iteration 50 completed in 12s
# Start of iteration 51
# Current loss value: 92356800.0
# Image saved as style_transfer_result_at_iteration_51.png
# Iteration 51 completed in 11s
# Start of iteration 52
# Current loss value: 91474190.0
# Image saved as style_transfer_result_at_iteration_52.png
# Iteration 52 completed in 12s
# Start of iteration 53
# Current loss value: 90547170.0
# Image saved as style_transfer_result_at_iteration_53.png
# Iteration 53 completed in 11s
# Start of iteration 54
# Current loss value: 89486584.0
# Image saved as style_transfer_result_at_iteration_54.png
# Iteration 54 completed in 12s
# Start of iteration 55
# Current loss value: 88521090.0
# Image saved as style_transfer_result_at_iteration_55.png
# Iteration 55 completed in 11s
# Start of iteration 56
# Current loss value: 86800620.0
# Image saved as style_transfer_result_at_iteration_56.png
# Iteration 56 completed in 12s
# Start of iteration 57
# Current loss value: 85410136.0
# Image saved as style_transfer_result_at_iteration_57.png
# Iteration 57 completed in 12s
# Start of iteration 58
# Current loss value: 84704730.0
# Image saved as style_transfer_result_at_iteration_58.png
# Iteration 58 completed in 12s
# Start of iteration 59
# Current loss value: 83998760.0
# Image saved as style_transfer_result_at_iteration_59.png
# Iteration 59 completed in 11s
# Start of iteration 60
# Current loss value: 83243590.0
# Image saved as style_transfer_result_at_iteration_60.png
# Iteration 60 completed in 11s
# Start of iteration 61
# Current loss value: 82685450.0
# Image saved as style_transfer_result_at_iteration_61.png
# Iteration 61 completed in 11s
# Start of iteration 62
# Current loss value: 80967120.0
# Image saved as style_transfer_result_at_iteration_62.png
# Iteration 62 completed in 12s
# Start of iteration 63
# Current loss value: 79439950.0
# Image saved as style_transfer_result_at_iteration_63.png
# Iteration 63 completed in 12s
# Start of iteration 64
# Current loss value: 78597360.0
# Image saved as style_transfer_result_at_iteration_64.png
# Iteration 64 completed in 11s
# Start of iteration 65
# Current loss value: 77983656.0
# Image saved as style_transfer_result_at_iteration_65.png
# Iteration 65 completed in 11s
# Start of iteration 66
# Current loss value: 77539670.0
# Image saved as style_transfer_result_at_iteration_66.png
# Iteration 66 completed in 12s
# Start of iteration 67
# Current loss value: 77092250.0
# Image saved as style_transfer_result_at_iteration_67.png
# Iteration 67 completed in 12s
# Start of iteration 68
# Current loss value: 76703080.0
# Image saved as style_transfer_result_at_iteration_68.png
# Iteration 68 completed in 12s
# Start of iteration 69
# Current loss value: 76316104.0
# Image saved as style_transfer_result_at_iteration_69.png
# Iteration 69 completed in 11s
# Start of iteration 70
# Current loss value: 75992780.0
# Image saved as style_transfer_result_at_iteration_70.png
# Iteration 70 completed in 11s
# Start of iteration 71
# Current loss value: 75610090.0
# Image saved as style_transfer_result_at_iteration_71.png
# Iteration 71 completed in 12s
# Start of iteration 72
# Current loss value: 75302584.0
# Image saved as style_transfer_result_at_iteration_72.png
# Iteration 72 completed in 11s
# Start of iteration 73
# Current loss value: 74911704.0
# Image saved as style_transfer_result_at_iteration_73.png
# Iteration 73 completed in 11s
# Start of iteration 74
# Current loss value: 74601330.0
# Image saved as style_transfer_result_at_iteration_74.png
# Iteration 74 completed in 11s
# Start of iteration 75
# Current loss value: 74078850.0
# Image saved as style_transfer_result_at_iteration_75.png
# Iteration 75 completed in 11s
# Start of iteration 76
# Current loss value: 73561980.0
# Image saved as style_transfer_result_at_iteration_76.png
# Iteration 76 completed in 12s
# Start of iteration 77
# Current loss value: 73154860.0
# Image saved as style_transfer_result_at_iteration_77.png
# Iteration 77 completed in 12s
# Start of iteration 78
# Current loss value: 72744690.0
# Image saved as style_transfer_result_at_iteration_78.png
# Iteration 78 completed in 11s
# Start of iteration 79
# Current loss value: 71994616.0
# Image saved as style_transfer_result_at_iteration_79.png
# Iteration 79 completed in 12s
# Start of iteration 80
# Current loss value: 71392744.0
# Image saved as style_transfer_result_at_iteration_80.png
# Iteration 80 completed in 11s
# Start of iteration 81
# Current loss value: 71123096.0
# Image saved as style_transfer_result_at_iteration_81.png
# Iteration 81 completed in 11s
# Start of iteration 82
# Current loss value: 70885336.0
# Image saved as style_transfer_result_at_iteration_82.png
# Iteration 82 completed in 12s
# Start of iteration 83
# Current loss value: 70657930.0
# Image saved as style_transfer_result_at_iteration_83.png
# Iteration 83 completed in 12s
# Start of iteration 84
# Current loss value: 70245290.0
# Image saved as style_transfer_result_at_iteration_84.png
# Iteration 84 completed in 12s
# Start of iteration 85
# Current loss value: 69900500.0
# Image saved as style_transfer_result_at_iteration_85.png
# Iteration 85 completed in 11s
# Start of iteration 86
# Current loss value: 69666870.0
# Image saved as style_transfer_result_at_iteration_86.png
# Iteration 86 completed in 12s
# Start of iteration 87
# Current loss value: 69340440.0
# Image saved as style_transfer_result_at_iteration_87.png
# Iteration 87 completed in 11s
# Start of iteration 88
# Current loss value: 69115360.0
# Image saved as style_transfer_result_at_iteration_88.png
# Iteration 88 completed in 12s
# Start of iteration 89
# Current loss value: 68756920.0
# Image saved as style_transfer_result_at_iteration_89.png
# Iteration 89 completed in 11s
# Start of iteration 90
# Current loss value: 68444750.0
# Image saved as style_transfer_result_at_iteration_90.png
# Iteration 90 completed in 11s
# Start of iteration 91
# Current loss value: 68092610.0
# Image saved as style_transfer_result_at_iteration_91.png
# Iteration 91 completed in 12s
# Start of iteration 92
# Current loss value: 67810210.0
# Image saved as style_transfer_result_at_iteration_92.png
# Iteration 92 completed in 12s
# Start of iteration 93
# Current loss value: 67483460.0
# Image saved as style_transfer_result_at_iteration_93.png
# Iteration 93 completed in 12s
# Start of iteration 94
# Current loss value: 67184536.0
# Image saved as style_transfer_result_at_iteration_94.png
# Iteration 94 completed in 11s
# Start of iteration 95
# Current loss value: 66858084.0
# Image saved as style_transfer_result_at_iteration_95.png
# Iteration 95 completed in 12s
# Start of iteration 96
# Current loss value: 66545990.0
# Image saved as style_transfer_result_at_iteration_96.png
# Iteration 96 completed in 14s
# Start of iteration 97
# Current loss value: 66268836.0
# Image saved as style_transfer_result_at_iteration_97.png
# Iteration 97 completed in 12s
# Start of iteration 98
# Current loss value: 65979200.0
# Image saved as style_transfer_result_at_iteration_98.png
# Iteration 98 completed in 12s
# Start of iteration 99
# Current loss value: 65779670.0
# Image saved as style_transfer_result_at_iteration_99.png
# Iteration 99 completed in 12s
# Start of iteration 100
# Current loss value: 65539750.0
# Image saved as style_transfer_result_at_iteration_100.png
# Iteration 100 completed in 12s
# Start of iteration 101
# Current loss value: 65353824.0
# Image saved as style_transfer_result_at_iteration_101.png
# Iteration 101 completed in 12s
# Start of iteration 102
# Current loss value: 65156310.0
# Image saved as style_transfer_result_at_iteration_102.png
# Iteration 102 completed in 12s
# Start of iteration 103
# Current loss value: 64950544.0
# Image saved as style_transfer_result_at_iteration_103.png
# Iteration 103 completed in 11s
# Start of iteration 104
# Current loss value: 64773376.0
# Image saved as style_transfer_result_at_iteration_104.png
# Iteration 104 completed in 12s
# Start of iteration 105
# Current loss value: 64610110.0
# Image saved as style_transfer_result_at_iteration_105.png
# Iteration 105 completed in 12s
# Start of iteration 106
# Current loss value: 64456676.0
# Image saved as style_transfer_result_at_iteration_106.png
# Iteration 106 completed in 12s
# Start of iteration 107
# Current loss value: 64184604.0
# Image saved as style_transfer_result_at_iteration_107.png
# Iteration 107 completed in 11s
# Start of iteration 108
# Current loss value: 63988260.0
# Image saved as style_transfer_result_at_iteration_108.png
# Iteration 108 completed in 12s
# Start of iteration 109
# Current loss value: 63828620.0
# Image saved as style_transfer_result_at_iteration_109.png
# Iteration 109 completed in 12s
# Start of iteration 110
# Current loss value: 63639852.0
# Image saved as style_transfer_result_at_iteration_110.png
# Iteration 110 completed in 12s
# Start of iteration 111
# Current loss value: 63384380.0
# Image saved as style_transfer_result_at_iteration_111.png
# Iteration 111 completed in 11s
# Start of iteration 112
# Current loss value: 63153260.0
# Image saved as style_transfer_result_at_iteration_112.png
# Iteration 112 completed in 12s
# Start of iteration 113
# Current loss value: 63004452.0
# Image saved as style_transfer_result_at_iteration_113.png
# Iteration 113 completed in 12s
# Start of iteration 114
# Current loss value: 62848190.0
# Image saved as style_transfer_result_at_iteration_114.png
# Iteration 114 completed in 11s
# Start of iteration 115
# Current loss value: 62668070.0
# Image saved as style_transfer_result_at_iteration_115.png
# Iteration 115 completed in 11s
# Start of iteration 116
# Current loss value: 62487764.0
# Image saved as style_transfer_result_at_iteration_116.png
# Iteration 116 completed in 12s
# Start of iteration 117
# Current loss value: 62325000.0
# Image saved as style_transfer_result_at_iteration_117.png
# Iteration 117 completed in 12s
# Start of iteration 118
# Current loss value: 62175530.0
# Image saved as style_transfer_result_at_iteration_118.png
# Iteration 118 completed in 11s
# Start of iteration 119
# Current loss value: 62038650.0
# Image saved as style_transfer_result_at_iteration_119.png
# Iteration 119 completed in 12s
# Start of iteration 120
# Current loss value: 61903252.0
# Image saved as style_transfer_result_at_iteration_120.png
# Iteration 120 completed in 12s
# Start of iteration 121
# Current loss value: 61751092.0
# Image saved as style_transfer_result_at_iteration_121.png
# Iteration 121 completed in 12s
# Start of iteration 122
# Current loss value: 61543892.0
# Image saved as style_transfer_result_at_iteration_122.png
# Iteration 122 completed in 11s
# Start of iteration 123
# Current loss value: 61365596.0
# Image saved as style_transfer_result_at_iteration_123.png
# Iteration 123 completed in 12s
# Start of iteration 124
# Current loss value: 61199590.0
# Image saved as style_transfer_result_at_iteration_124.png
# Iteration 124 completed in 11s
# Start of iteration 125
# Current loss value: 61035028.0
# Image saved as style_transfer_result_at_iteration_125.png
# Iteration 125 completed in 11s
# Start of iteration 126
# Current loss value: 60858536.0
# Image saved as style_transfer_result_at_iteration_126.png
# Iteration 126 completed in 11s
# Start of iteration 127
# Current loss value: 60685228.0
# Image saved as style_transfer_result_at_iteration_127.png
# Iteration 127 completed in 12s
# Start of iteration 128
# Current loss value: 60391308.0
# Image saved as style_transfer_result_at_iteration_128.png
# Iteration 128 completed in 12s
# Start of iteration 129
# Current loss value: 60148160.0
# Image saved as style_transfer_result_at_iteration_129.png
# Iteration 129 completed in 12s
# Start of iteration 130
# Current loss value: 59939400.0
# Image saved as style_transfer_result_at_iteration_130.png
# Iteration 130 completed in 11s
# Start of iteration 131
# Current loss value: 59731744.0
# Image saved as style_transfer_result_at_iteration_131.png
# Iteration 131 completed in 12s
# Start of iteration 132
# Current loss value: 59607520.0
# Image saved as style_transfer_result_at_iteration_132.png
# Iteration 132 completed in 12s
# Start of iteration 133
# Current loss value: 59491076.0
# Image saved as style_transfer_result_at_iteration_133.png
# Iteration 133 completed in 11s
# Start of iteration 134
# Current loss value: 59366588.0
# Image saved as style_transfer_result_at_iteration_134.png
# Iteration 134 completed in 11s
# Start of iteration 135
# Current loss value: 59247230.0
# Image saved as style_transfer_result_at_iteration_135.png
# Iteration 135 completed in 11s
# Start of iteration 136
# Current loss value: 59138892.0
# Image saved as style_transfer_result_at_iteration_136.png
# Iteration 136 completed in 11s
# Start of iteration 137
# Current loss value: 59033684.0
# Image saved as style_transfer_result_at_iteration_137.png
# Iteration 137 completed in 12s
# Start of iteration 138
# Current loss value: 58914190.0
# Image saved as style_transfer_result_at_iteration_138.png
# Iteration 138 completed in 11s
# Start of iteration 139
# Current loss value: 58800884.0
# Image saved as style_transfer_result_at_iteration_139.png
# Iteration 139 completed in 12s
# Start of iteration 140
# Current loss value: 58669916.0
# Image saved as style_transfer_result_at_iteration_140.png
# Iteration 140 completed in 13s
# Start of iteration 141
# Current loss value: 58540040.0
# Image saved as style_transfer_result_at_iteration_141.png
# Iteration 141 completed in 11s
# Start of iteration 142
# Current loss value: 58433284.0
# Image saved as style_transfer_result_at_iteration_142.png
# Iteration 142 completed in 12s
# Start of iteration 143
# Current loss value: 58310040.0
# Image saved as style_transfer_result_at_iteration_143.png
# Iteration 143 completed in 12s
# Start of iteration 144
# Current loss value: 58193056.0
# Image saved as style_transfer_result_at_iteration_144.png
# Iteration 144 completed in 11s
# Start of iteration 145
# Current loss value: 58045476.0
# Image saved as style_transfer_result_at_iteration_145.png
# Iteration 145 completed in 11s
# Start of iteration 146
# Current loss value: 57919988.0
# Image saved as style_transfer_result_at_iteration_146.png
# Iteration 146 completed in 12s
# Start of iteration 147
# Current loss value: 57817876.0
# Image saved as style_transfer_result_at_iteration_147.png
# Iteration 147 completed in 11s
# Start of iteration 148
# Current loss value: 57693280.0
# Image saved as style_transfer_result_at_iteration_148.png
# Iteration 148 completed in 11s
# Start of iteration 149
# Current loss value: 57586092.0
# Image saved as style_transfer_result_at_iteration_149.png
# Iteration 149 completed in 12s

# %%
from matplotlib import pyplot as plt

# Content image
print('Content image')
plt.imshow(load_img(target_image_path, target_size=(img_height, img_width)))
plt.figure()

# Style image
print('Style image')
plt.imshow(load_img(style_reference_image_path, target_size=(img_height, img_width)))
plt.figure()

# Generate image
print('Generated image')
plt.imshow(img)
plt.show()
# Out:
# Content image
# Style image
# Generated image
